# %%
import sqlite3
import pandas as pd

with sqlite3.connect("dataset.db") as conn:
    cpi_df = pd.read_sql("SELECT * FROM cpi;", conn)

# %%
cpi_df[
    cpi_df["country_name"].isin(
        ["Japan", "United Kingdom", "United States", "Australia"]
    )
].sort_values(["country_name", "date"])
# Out:
#      countryiso3code    country_name  date       value
# 102              AUS       Australia  2010  100.000000
# 101              AUS       Australia  2011  103.303850
# 100              AUS       Australia  2012  105.124870
# 99               AUS       Australia  2013  107.700312
# 98               AUS       Australia  2014  110.379813
# 97               AUS       Australia  2015  112.044745
# 96               AUS       Australia  2016  113.475546
# 95               AUS       Australia  2017  115.686785
# 94               AUS       Australia  2018  117.898023
# 93               AUS       Australia  2019  119.797086
# 92               AUS       Australia  2020  120.811655
# 91               AUS       Australia  2021  124.271592
# 90               AUS       Australia  2022  132.466181
# 89               AUS       Australia  2023  139.880333
# 1130             JPN           Japan  2010  100.000000
# 1129             JPN           Japan  2011   99.727544
# ...
